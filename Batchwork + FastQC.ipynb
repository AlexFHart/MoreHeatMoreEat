# %% [markdown]
# ### Batch set up and FASTQC loop for HS/MR dataset
#
# 1. set up batches like 20 samples per batch?
# 2. totally ignore the batches and process samples in a big list
# 3. jam them into a FastQC script
# 4. ???
# 5. profit

# %%
# /proj/sexsel_data/snic2020-16-129_whole_project_directory/private/HS_MR_remake

# %%
# Mating Response batches

#!/bin/bash
#SBATCH -J MR_Batch_1
#SBATCH -A naiss2023-5-472

for sample in AV3_S55 AV2_S54 AV1_S53 ALH_S52 ALG_S51 ALF_S50 ALE_S49 ALD_S48 ALC_S47 ALB_S46 ALA_S45 AFH_S44 AFG_S43 AFF_S42
do
    sbatch SCRIPT.sh "$sample"
done



#!/bin/bash
#SBATCH -J MR_Batch_2
#SBATCH -A naiss2023-5-472

for sample in AFE_S41 AFD_S40 AFC_S39 AFB_S38 AFA_S37 AMH_S36 AMG_S35 AMF_S34 AME_S33 AMD_S32 AMC_S31 AMB_S30 AMA_S29
do
    sbatch SCRIPT.sh "$sample"
done

# %%
# Heat Stress batches

#!/bin/bash
#SBATCH -J MR_Batch_1
#SBATCH -A naiss2023-5-472

for sample in FM1L1 FM1L2 FM1M1 FM1M2 FM1S1 FM1S2 FM2L4 FM2M1 FM2M4 FM2S1 FM2S2 FM3L1 FM3L7 FM3M1 FM3S1
do
    sbatch SCRIPT.sh "$sample"
done



#!/bin/bash
#SBATCH -J MR_Batch_1
#SBATCH -A naiss2023-5-472

for sample in FST1L1 FST1L2 FST1L5 FST1M1 FST1M2 FST1S1 FST1S2 FST1S5 FST2L4 FST2L7 FST2M1 FST2M2 FST2S1 FST2S2 FST3L1 FST3L7 FST3M1 FST3M2 FST3M5 FST3S1 FST3S2
do
    sbatch SCRIPT.sh "$sample"
done



#!/bin/bash
#SBATCH -J MR_Batch_1
#SBATCH -A naiss2023-5-472

for sample in HS1L1 HS1L2 HS1L7 HS1M1 HS1M2 HS1S1 HS1S2 HS2L4 HS2M1 HS2S1 HS2S2 HS3L1 HS3M1 HS3M2 HS3S1
do
    sbatch SCRIPT.sh "$sample"
done



#!/bin/bash
#SBATCH -J MR_Batch_1
#SBATCH -A naiss2023-5-472

for sample in IRR1L1 IRR1M1 IRR1S1 IRR1S2 IRR2L4 IRR2L7 IRR2M1 IRR2M2 IRR2S1 IRR2S2 IRR3L1 IRR3L4 IRR3M1 IRR3M2
do
    sbatch SCRIPT.sh "$sample"
done



#!/bin/bash
#SBATCH -J MR_Batch_1
#SBATCH -A naiss2023-5-472

for sample in IRR3S1 TRD1L1 TRD1M1 TRD1S1 TRD2L4 TRD2L7 TRD2M1 TRD2M2 TRD2S1 TRD2S2 TRD3L1 TRD3L7 TRD3M1 TRD3M2 TRD3S1 TRD3S2
do
    sbatch SCRIPT.sh "$sample"
done

# %%
# FastQC for HS

#!/bin/bash -l
#SBATCH -J fastqc_loop_HS
#SBATCH -A naiss2023-5-472
#SBATCH -p core 
#SBATCH -n 4
#SBATCH -t 14:00:00

module load bioinfo-tools
module load FastQC/0.11.9

fastqc --threads 4 \
-o /proj/sexsel_data/snic2020-16-129_whole_project_directory/private/HS_MR_remake/FastQC \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1L1/UH-3042-FM1L1_S79_L004_R1_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1L1/UH-3042-FM1L1_S79_L004_R2_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1L2/UH-3042-FM1L2_S39_L004_R1_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1L2/UH-3042-FM1L2_S39_L004_R2_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1M1/UH-3042-FM1M1_S69_L004_R1_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1M1/UH-3042-FM1M1_S69_L004_R2_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1M2/UH-3042-FM1M2_S33_L004_R1_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1M2/UH-3042-FM1M2_S33_L004_R2_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1S1/UH-3042-FM1S1_S64_L004_R1_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1S1/UH-3042-FM1S1_S64_L004_R2_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1S2/UH-3042-FM1S2_S30_L004_R1_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM1S2/UH-3042-FM1S2_S30_L004_R2_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM2L4/UH-3042-FM2L4_S54_L004_R1_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM2L4/UH-3042-FM2L4_S54_L004_R2_001.fastq.gz \
/proj/sexsel_data/snic2020-16-129_whole_project_directory/private/RNA/UH-3042/211015_A00181_0359_AHJYYLDSX2/Sample_UH-3042-FM